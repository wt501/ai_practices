# %%
# おまじない
from sklearn.linear_model import LinearRegression

lr = LinearRegression()         # 線形回帰モデルを定義
x = [[1], [4], [5], [12], [20]] # 説明変数
y = [43, 65, 88, 120, 230]      # 目的変数

lr.fit(x, y)            # 学習スタート
a = lr.coef_[0]         # 傾き
b = lr.intercept_       # 切片
print(f"{a}x + {b}")    # 直線の式の表示
# Out:
# 9.419382504288166x + 30.077186963979415

# %%
lr = LinearRegression()
x = [[240], [60], [20], [180], [300]]
y = [432, 350, 151, 478, 401]

lr.fit(x, y)
a = lr.coef_[0]
b = lr.intercept_
print(f"{a}x + {b}")
# Out:
# 0.7878571428571426x + 236.34285714285716
